# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
      def invertTree(self, root: TreeNode) -> TreeNode:
            if not root:
                return root
            left=slef.invertTree(root.left)
            right=slef.invertTree(root,right)
            root.left,root.right=right,left
            return root
